# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the data

# %%
df = pd.read_csv("customer.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df = df.drop(['customerID'], axis = 1)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# Feature Engineering

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['gender'] = le.fit_transform(df['gender'])

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       0              0     Yes         No       1           No
# 1       1              0      No         No      34          Yes
# 2       1              0      No         No       2          Yes
# 3       1              0      No         No      45           No
# 4       0              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df['SeniorCitizen'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: SeniorCitizen
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   int64
# dtypes: int64(1)
# memory usage: 55.1 KB

# %%
df['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Partner'] = le.fit_transform(df['Partner'])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner Dependents  tenure PhoneService  \
# 0       0              0        1         No       1           No
# 1       1              0        0         No      34          Yes
# 2       1              0        0         No       2          Yes
# 3       1              0        0         No      45           No
# 4       0              0        0         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df['Dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Dependents'] = le.fit_transform(df['Dependents'])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure PhoneService  \
# 0       0              0        1           0       1           No
# 1       1              0        0           0      34          Yes
# 2       1              0        0           0       2          Yes
# 3       1              0        0           0      45           No
# 4       0              0        0           0       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df['tenure'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: tenure
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   int64
# dtypes: int64(1)
# memory usage: 55.1 KB

# %%
df['PhoneService'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['PhoneService'] = le.fit_transform(df['PhoneService'])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df['MultipleLines'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: MultipleLines
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 55.1+ KB

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df['MultipleLines'] = le.fit_transform(df['MultipleLines'])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0              1             DSL             No          Yes               No
# 1              0             DSL            Yes           No              Yes
# 2              0             DSL            Yes          Yes               No
# 3              1             DSL            Yes           No              Yes
# 4              0     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df['MultipleLines'].unique()
# Out:
# array([1, 0, 2])

# %%
df['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['InternetService'] = le.fit_transform(df['InternetService'])

# %%
df['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
def encoder(feat):
    df[feat] = le.fit_transform(df[feat])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 0              1                0             No          Yes
# 1              0                0            Yes           No
# 2              0                0            Yes          Yes
# 3              1                0            Yes           No
# 4              0                1             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
lst = ["OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport","SteamingTV", "StreamingMovies", "Contract", "PaperlessBilling", "PaymentMethod"]

# %%
df["MonthlyCharges"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: MonthlyCharges
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   float64
# dtypes: float64(1)
# memory usage: 55.1 KB

# %%
df["TotalCharges"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 55.1+ KB

# %%
df["TotalCharges"].unique()
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
median_charge = df["TotalCharges"].median

# %%
df["TotalCharges"].replace('',median_charge,inplace = True )

# %%
df["TotalCharges"].unique()
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 0              1                0             No          Yes
# 1              0                0            Yes           No
# 2              0                0            Yes          Yes
# 3              1                0            Yes           No
# 4              0                1             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
lst = ['OnlineSecurity',
       'OnlineBackup',
       'DeviceProtection',
       'TechSupport',
       'StreamingTV',
       'Contract',
       'PaperlessBilling',
       'PaymentMethod']

# %%
for l in lst:
    encoder(l)

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV StreamingMovies  Contract  \
# 0                 0            0            0              No         0
# ...

# %%
encoder("StreamingMovies")

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df['TotalCharges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 55.1+ KB

# %%
charges  = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
failed_rows = df[charges.isna()]

# %%
failed_rows
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        0              0        1           1       0             0
# 753        1              0        0           1       0             1
# 936        0              0        1           1       0             1
# 1082       1              0        1           1       0             1
# 1340       0              0        1           1       0             0
# 3331       1              0        1           1       0             1
# 3826       1              0        1           1       0             1
# 4380       0              0        1           1       0             1
# 5218       1              0        1           1       0             1
# 6670       0              0        1           1       0             1
# 6754       1              0        0           1       0             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
Charges_med = df["TotalCharges"].median

# %%
failed_rows
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        0              0        1           1       0             0
# 753        1              0        0           1       0             1
# 936        0              0        1           1       0             1
# 1082       1              0        1           1       0             1
# 1340       0              0        1           1       0             0
# 3331       1              0        1           1       0             1
# 3826       1              0        1           1       0             1
# 4380       0              0        1           1       0             1
# 5218       1              0        1           1       0             1
# 6670       0              0        1           1       0             1
# 6754       1              0        0           1       0             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
charges  = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
failed_rows = df[charges.isna()]

# %%
failed_rows
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        0              0        1           1       0             0
# 753        1              0        0           1       0             1
# 936        0              0        1           1       0             1
# 1082       1              0        1           1       0             1
# 1340       0              0        1           1       0             0
# 3331       1              0        1           1       0             1
# 3826       1              0        1           1       0             1
# 4380       0              0        1           1       0             1
# 5218       1              0        1           1       0             1
# 6670       0              0        1           1       0             1
# 6754       1              0        0           1       0             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
lst2 = [488,
        753,
        936,
        1082,
        1340,
        3331,
        3826,
        4380,
        5218,
        6670,
        6754
        ]

# %%
charges = charges[charges.isna()==0]
charges = charges.astype(float)
Charges_med = charges.median()

# %%
print(charges)
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
print(Charges_med)
# Out:
# 1397.475

# %%
for l in lst2:
    df["TotalCharges"].loc[l] = Charges_med
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17264\2296548029.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TotalCharges"].loc[l] = Charges_med

# %%
df["TotalCharges"] = df["TotalCharges"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int32
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int32
#  6   MultipleLines     7043 non-null   int32
#  7   InternetService   7043 non-null   int32
#  8   OnlineSecurity    7043 non-null   int32
#  9   OnlineBackup      7043 non-null   int32
#  10  DeviceProtection  7043 non-null   int32
#  11  TechSupport       7043 non-null   int32
#  12  StreamingTV       7043 non-null   int32
#  13  StreamingMovies   7043 non-null   int32
#  14  Contract          7043 non-null   int32
#  15  PaperlessBilling  7043 non-null   int32
# ...

# %%
df['Churn'] = le.fit_transform(df['Churn'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int32
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int32
#  6   MultipleLines     7043 non-null   int32
#  7   InternetService   7043 non-null   int32
#  8   OnlineSecurity    7043 non-null   int32
#  9   OnlineBackup      7043 non-null   int32
#  10  DeviceProtection  7043 non-null   int32
#  11  TechSupport       7043 non-null   int32
#  12  StreamingTV       7043 non-null   int32
#  13  StreamingMovies   7043 non-null   int32
#  14  Contract          7043 non-null   int32
#  15  PaperlessBilling  7043 non-null   int32
# ...

# %% [markdown]
# EDA

# %%
import seaborn as sns

# %%
sns.barplot( x = 'Churn', y = 'tenure', data = df)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
lst = df.columns

# %%
lst
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
lst = list[lst]

# %%
print(lst)
# Out:
# list[Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')]

# %%
# for l in lst:
#     sns.barplot( x = 'Churn', y = l, data = df)
#     plt.show()

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
churn = df['Churn'].value_counts()
churn
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
plt.figure(figsize=(4,6))
my_palette = ['#ff9999','#66b3ff']
plt.pie(churn,colors=my_palette,autopct='%1.1f%%',labels=['No','Yes'])
plt.title('Churn')
plt.show()

# %%
# gender = df['gender'].value_counts()
# plt.pie(gender, colors = my_palette, labels=gender.index, autopct='%1.1f%%')

# %% [markdown]
# ## Model

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
X = df.drop(["Churn"], axis = 1)
y = df["Churn"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X.values, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import pickle
pickle.dump(sc, open('scaler.pkl','wb'))

# %%
X.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU, PReLU, ELU
from keras.layers import Dropout
from keras.optimizers import SGD, Adam

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units = 10, kernel_initializer = 'he_uniform',activation='relu',input_dim = 19))
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model_history = classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 378/378 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7210 - val_loss: 0.4512 - val_accuracy: 0.7559
# Epoch 2/100
# 378/378 [==============================] - 1s 2ms/step - loss: 0.4782 - accuracy: 0.7239 - val_loss: 0.4384 - val_accuracy: 0.7661
# Epoch 3/100
# 378/378 [==============================] - 1s 2ms/step - loss: 0.4623 - accuracy: 0.7528 - val_loss: 0.4328 - val_accuracy: 0.7737
# Epoch 4/100
# 378/378 [==============================] - 1s 2ms/step - loss: 0.4524 - accuracy: 0.7695 - val_loss: 0.4320 - val_accuracy: 0.7817
# Epoch 5/100
# 378/378 [==============================] - 1s 2ms/step - loss: 0.4456 - accuracy: 0.7809 - val_loss: 0.4274 - val_accuracy: 0.7860
# Epoch 6/100
# 378/378 [==============================] - 1s 3ms/step - loss: 0.4403 - accuracy: 0.7859 - val_loss: 0.4274 - val_accuracy: 0.7882
# Epoch 7/100
# ...

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 45/45 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[899, 142],
#        [166, 202]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.7814052519517388

# %% [markdown]
# Hyperparameter tuning

# %%
def build_model(hp):
    model = Sequential()
    counter=0
    for i in range(3):
        
        if counter==0:
            model.add(
                Dense(
                    hp.Int('units'+str(i), min_value=1, max_value=20, step=1),
                    activation=hp.Choice('act'+str(i), values=['relu','tanh','sigmoid']),
                    input_dim=19  
                )
                )
            model.add(Dropout(hp.Choice('dropout'+str(i), values=[0.1,0.2,0.3,0.4])))
        else:
            model.add(
                Dense(
                    hp.Int('units'+str(i), min_value=1, max_value=20, step=1),
                    activation=hp.Choice('act'+str(i), values=['relu','tanh','sigmoid'])
                )
                )
        counter+=1
        
    model.add(Dense(1,activation='sigmoid'))
    
    model.compile(optimizer=hp.Choice('optmizer', values=['rmsprop','adam','sgd']),
                 loss = 'binary_crossentropy',
                 metrics=['accuracy']
                 )
    
    return model

# %%
import keras_tuner as kt

# %%
tuner = kt.RandomSearch(build_model, objective='val_accuracy', max_trials=15, directory='mydir', project_name='finalfinalfinalfinal')

# %%
tuner.search(X_train, y_train, epochs=5, validation_data = (X_test, y_test))
# Out:
# Trial 15 Complete [00h 00m 04s]
# val_accuracy: 0.782824695110321
#
# Best val_accuracy So Far: 0.7941802740097046
# Total elapsed time: 00h 01m 03s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'units0': 20,
#  'act0': 'tanh',
#  'dropout0': 0.3,
#  'units1': 15,
#  'act1': 'sigmoid',
#  'units2': 18,
#  'act2': 'sigmoid',
#  'optmizer': 'adam'}

# %%
classifier = tuner.get_best_models(num_models=1)[0]

# %%
classifier.fit(X_train, y_train, epochs=200, initial_epoch=7, validation_data=(X_test, y_test))
# Out:
# Epoch 8/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4320 - accuracy: 0.7923 - val_loss: 0.4477 - val_accuracy: 0.7878
# Epoch 9/200
# 177/177 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.7911 - val_loss: 0.4468 - val_accuracy: 0.7906
# Epoch 10/200
# 177/177 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.7955 - val_loss: 0.4449 - val_accuracy: 0.7935
# Epoch 11/200
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.7971 - val_loss: 0.4464 - val_accuracy: 0.7878
# Epoch 12/200
# 177/177 [==============================] - 0s 2ms/step - loss: 0.4271 - accuracy: 0.7918 - val_loss: 0.4437 - val_accuracy: 0.7949
# Epoch 13/200
# 177/177 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.7985 - val_loss: 0.4432 - val_accuracy: 0.7906
# Epoch 14/200
# ...

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 45/45 [==============================] - 0s 1ms/step

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[917, 124],
#        [175, 193]], dtype=int64)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7877927608232789

# %% [markdown]
# Pickling the Model file for Deployment

# %%
import pickle

# %%
# pickle.dump(classifier, open('classifier.pkl','wb'))

# %%
pickled_model = pickle.load(open('classifier.pkl','rb'))

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
data = {"data":
{
"gender":0,
"SeniorCitizen":0,
"Partner":1,
"Dependents":0,
"tenure":1,
"PhoneService":0,
"MultipleLines":1,
"InternetService":0,
"OnlineSecurity":0,
"OnlineBackup":2,
"DeviceProtection":0,
"TechSupport":0,
"StreamingTV":0,
"StreamingMovies":0,
"Contract":0,
"PaperlessBilling":1,
"PaymentMethod":2, 
"MonthlyCharges":29.85,
"TotalCharges":29.85
}}

# %%
c = np.array(list(data.values())).reshape(1,-1)

# %%
print(c)
# Out:
# [[{'gender': 0, 'SeniorCitizen': 0, 'Partner': 1, 'Dependents': 0, 'tenure': 1, 'PhoneService': 0, 'MultipleLines': 1, 'InternetService': 0, 'OnlineSecurity': 0, 'OnlineBackup': 2, 'DeviceProtection': 0, 'TechSupport': 0, 'StreamingTV': 0, 'StreamingMovies': 0, 'Contract': 0, 'PaperlessBilling': 1, 'PaymentMethod': 2, 'MonthlyCharges': 29.85, 'TotalCharges': 29.85}]]

# %%
d = data.values()

# %%
print(d)
# Out:
# dict_values([{'gender': 0, 'SeniorCitizen': 0, 'Partner': 1, 'Dependents': 0, 'tenure': 1, 'PhoneService': 0, 'MultipleLines': 1, 'InternetService': 0, 'OnlineSecurity': 0, 'OnlineBackup': 2, 'DeviceProtection': 0, 'TechSupport': 0, 'StreamingTV': 0, 'StreamingMovies': 0, 'Contract': 0, 'PaperlessBilling': 1, 'PaymentMethod': 2, 'MonthlyCharges': 29.85, 'TotalCharges': 29.85}])

# %%
new_data = sc.transform(np.array(list(c)).reshape(1,-1))
output = classifier.predict(new_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 new_data = sc.transform(np.array(list(c)).reshape(1,-1))
#       2 output = classifier.predict(new_data)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:992, in StandardScaler.transform(self, X, copy)
# ...

# %%
data = {
"gender":0,
"SeniorCitizen":0,
"Partner":1,
"Dependents":0,
"tenure":1,
"PhoneService":0,
"MultipleLines":1,
"InternetService":0,
"OnlineSecurity":0,
"OnlineBackup":2,
"DeviceProtection":0,
"TechSupport":0,
"StreamingTV":0,
"StreamingMovies":0,
"Contract":0,
"PaperlessBilling":1,
"PaymentMethod":2, 
"MonthlyCharges":29.85,
"TotalCharges":29.85
}

# %%
data.values()
# Out:
# dict_values([0, 0, 1, 0, 1, 0, 1, 0, 0, 2, 0, 0, 0, 0, 0, 1, 2, 29.85, 29.85])

# %%
c = np.array(list(data.values())).reshape(1,-1)

# %%
print(c)
# Out:
# [[ 0.    0.    1.    0.    1.    0.    1.    0.    0.    2.    0.    0.
#    0.    0.    0.    1.    2.   29.85 29.85]]

# %%
new_data = sc.transform(c)
output = classifier.predict(c)
output = int(output > 0.5)
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
print(output)
# Out:
# 1

# %%
from flask import jsonify

# %%
new = {"data":{
"gender":0,
"SeniorCitizen":0,
"Partner":1,
"Dependents":0,
"tenure":1,
"PhoneService":0,
"MultipleLines":1,
"InternetService":0,
"OnlineSecurity":0,
"OnlineBackup":2,
"DeviceProtection":0,
"TechSupport":0,
"StreamingTV":0,
"StreamingMovies":0,
"Contract":0,
"PaperlessBilling":1,
"PaymentMethod":2, 
"MonthlyCharges":29.85,
"TotalCharges":29.85
}}

# %%
my_dict = new
my_list = list(my_dict["data"].values())
print(my_list)
# Out:
# [0, 0, 1, 0, 1, 0, 1, 0, 0, 2, 0, 0, 0, 0, 0, 1, 2, 29.85, 29.85]
